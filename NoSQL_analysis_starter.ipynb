# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
#Import dependencies:
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
#Create an instance of MongoClient:
mongo = MongoClient(port=27017)

# %%
#Assign the uk_food database to a variable name:
db = mongo['uk_food']

# %%
#Review the collections in our database:
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
#Assign the 'collection' to a variable:
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
#Find the establishments with a hygiene score of 20:
hygiene_query = {'scores.Hygiene' : {'$eq':20}}

#Use count_documents to display the number of documents in the result:
count = establishments.count_documents(hygiene_query)
print(f"Number of documents in the result: {count}")

#Display the first document in the results using pprint:
pprint(establishments.find_one(hygiene_query))
# Out:
# Number of documents in the result: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64fa60f6ebfc9f4c393d0805'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
#Convert the result to a Pandas DataFrame:
hygiene_data = pd.DataFrame(establishments.find(hygiene_query))

#Display the number of rows in the DataFrame:
print(f"Number of Rows in DataFrame: {len(hygiene_data)}")

#Display the first 10 rows of the DataFrame:
hygiene_data.head()
# Out:
# Number of Rows in DataFrame: 41
#                         _id  FHRSID  ChangesByServerID  \
# 0  64fa60f6ebfc9f4c393d0805  110681                  0
# 1  64fa60f6ebfc9f4c393d0b89  612039                  0
# 2  64fa60f6ebfc9f4c393d0e8e  730933                  0
# 3  64fa60f6ebfc9f4c393d107e  172735                  0
# 4  64fa60f6ebfc9f4c393d108e  172953                  0
#
#   LocalAuthorityBusinessID         BusinessName  \
# 0                     4029  The Chase Rest Home
# 1                1970/FOOD           Brenalwood
# 2                1698/FOOD        Melrose Hotel
# 3             PI/000023858        Seaford Pizza
# 4             PI/000024532        Golden Palace
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
#Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4:
london_query = {'LocalAuthorityName': {'$regex':'London'},'RatingValue': {'$gte':4}}

#Use count_documents to display the number of documents in the result:
rating_value = establishments.count_documents(london_query)

# Display the first document in the results using pprint:
pprint(establishments.find_one(london_query))
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64fa60f7ebfc9f4c393d221d'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
#Convert the result to a Pandas DataFrame:
rating_data = pd.DataFrame(establishments.find(london_query))

#Display the number of rows in the DataFrame:
print(f"Number of Rows in DataFrame: {len(rating_data)}")

#Display the first 10 rows of the DataFrame:
rating_data.head()
# Out:
# Number of Rows in DataFrame: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  64fa60f7ebfc9f4c393d221d   621707                  0
# 1  64fa60f7ebfc9f4c393d2546  1130836                  0
# 2  64fa60f7ebfc9f4c393d3093   293783                  0
# 3  64fa60f7ebfc9f4c393d3e92  1315095                  0
# 4  64fa60f7ebfc9f4c393d3e94   294474                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#Search within 0.01 degree on either side of the latitude and longitude.:
degree_search = 0.01
latitude = 51.369321
longitude = 0.508551

#Rating value must equal 5:
top5_query = {'RatingValue': 5,
              'geocode.longitude' : {'$lte' : (longitude + degree_search), '$gte' : (longitude - degree_search)},
              'geocode.latitude' : {'$lte' : (latitude + degree_search), '$gte' : (latitude - degree_search)}
             }

#Sort by hygiene score:
sort = [('scores.Hygiene', 1)]
limit = 5

#Print the results:
pprint(list(establishments.find(top5_query).sort(sort).limit(limit)))
# Out:
# [{'AddressLine1': '1 Beatty Road',
#   'AddressLine2': 'Rochester',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Papas Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4627.165001454627,
#   'FHRSID': 605582,
#   'LocalAuthorityBusinessID': 'PI/000002322',
#   'LocalAuthorityCode': '896',
#   'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#   'LocalAuthorityName': 'Medway',
#   'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'ME1 2TG',
#   'RatingDate': '2020-11-18T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64fa60f6ebfc9f4c393d2095'),
#   'geocode': {'latitude': 51.363931, 'longitude': 0.510609},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/605582',
# ...

# %%
#Convert result to Pandas DataFrame:
top5_data = pd.DataFrame(establishments.find(top5_query).sort(sort).limit(limit))
top5_data.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64fa60f6ebfc9f4c393d2095   605582                  0
# 1  64fa60f6ebfc9f4c393d2092   783911                  0
# 2  64fa60f7ebfc9f4c393d20ee   683394                  0
# 3  64fa60f7ebfc9f4c393d20aa  1079636                  0
# 4  64fa60f6ebfc9f4c393d202f   786158                  0
#
#   LocalAuthorityBusinessID             BusinessName            BusinessType  \
# 0             PI/000002322           Papas Fish Bar  Takeaway/sandwich shop
# 1             PI/000002329                 One Stop       Retailers - other
# 2             PI/000187947  Warren Wood Social Club       Retailers - other
# 3              18/00543/CP                 Our Zone         Caring Premises
# 4             PI/000030142                News Shop       Retailers - other
#
#    BusinessTypeID          AddressLine1 AddressLine2 AddressLine3  ...  \
# 0            7844         1 Beatty Road    Rochester         Kent  ...
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
#Create a pipeline that: 
#1. Matches establishments with a hygiene score of 0:
match_query = {'$match' : {'scores.Hygiene' : 0}}

#2. Groups the matches by Local Authority:
group_query = {'$group' : {'_id' : '$LocalAuthorityName', 'count' : {'$sum' : 1}}}

#3. Sorts the matches from highest to lowest:
query_sorted = {'$sort' : {'count' : -1}}
pipeline = [match_query, group_query, query_sorted]

#Print the number of documents in the result
results_data = list(establishments.aggregate(pipeline))
print(f"Number of Documents in the Result Are : {len(results_data)}")

#Print the first 10 results
pprint(results_data[0:10])
# Out:
# Number of Documents in the Result Are : 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
#Convert the result to a Pandas DataFrame:
hygiene_score_df = pd.DataFrame(results_data)

#Display the number of rows in the DataFrame:
print(f"There are {len(hygiene_score_df)} Rows in this DataFrame.")

#Display the first 10 rows of the DataFrame:
hygiene_score_df.head(10)
# Out:
# There are 55 Rows in this DataFrame.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
